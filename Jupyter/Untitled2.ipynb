# %%
import math
import numpy as np
import seaborn as sns

# %% [markdown]
# # Matriz de pesos - 1a. capa

# %%
w1 = np.array([
[-1.61638641835525,1.48781463143557],
[0.661360137558272,0.14542716844971],
[1.87635253510075,0.258927555953536],
[-0.761919127010929,0.215676880539242],
[1.09994696413337,0.752669291138465]

])

# %%
w2 = np.array([
[-1.15225220299697,-23.9015113364388,0.486311052226944],
[0.504567530636415,-18.0324122222704,-476.404089869933],
[-0.512662625454625,221.657324246666,0.18996302794802]
])

# %%
w3 = np.array([
[0.000474155890345046,0.585009107410016,0.430229281036369],
[-0.00140877024434706,-1.7517867821674,1.70641513303126],
[-6.39258019657287e-05,0.90011822826787,-0.902139385069451],
[1.50891586591292,-1.81939568843917,0.301206998960122]
])

# %%
def f_act(X):
    activada = []
    for x in X:
        try: 
            r = 1 / (1 + math.exp(-x))
        except OverflowError:
            r = 0
        activada.append(r)
    return np.array(activada)

# %%
#Carga de datos
iris =sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
xcols = ['sepal_length','sepal_width','petal_length','petal_width']
especie = iris['species'].unique()
especie
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
X = iris[xcols].copy()
X.insert(0,'bias',1)
X
# Out:
#      bias  sepal_length  sepal_width  petal_length  petal_width
# 0       1           5.1          3.5           1.4          0.2
# 1       1           4.9          3.0           1.4          0.2
# 2       1           4.7          3.2           1.3          0.2
# 3       1           4.6          3.1           1.5          0.2
# 4       1           5.0          3.6           1.4          0.2
# ..    ...           ...          ...           ...          ...
# 145     1           6.7          3.0           5.2          2.3
# 146     1           6.3          2.5           5.0          1.9
# 147     1           6.5          3.0           5.2          2.0
# 148     1           6.2          3.4           5.4          2.3
# 149     1           5.9          3.0           5.1          1.8
#
# [150 rows x 5 columns]

# %%
#Prediccion 
prediccion = []
for index, fila in X.iterrows():
    capa1 = f_act(fila.dot(w1))
    capa1 = np.insert(capa1,0,1)
    capa2 = f_act(capa1.dot(w2))
    capa2 = np.insert(capa2,0,1)
    salida = f_act(capa2.dot(w3))
    prediccion.append(especie[np.argmax(salida)])

# %%
iris['Prediccion'] = prediccion
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  Prediccion
# 0           5.1          3.5           1.4          0.2  setosa  versicolor
# 1           4.9          3.0           1.4          0.2  setosa  versicolor
# 2           4.7          3.2           1.3          0.2  setosa  versicolor
# 3           4.6          3.1           1.5          0.2  setosa  versicolor
# 4           5.0          3.6           1.4          0.2  setosa  versicolor

# %%
iris.iloc[73:78]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 73           6.1          2.8           4.7          1.2  versicolor
# 74           6.4          2.9           4.3          1.3  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
#
#     Prediccion
# 73  versicolor
# 74  versicolor
# 75  versicolor
# 76  versicolor
# 77  versicolor

# %%
errores = iris[iris['species']!=iris['Prediccion']]
errores
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      Prediccion
# 0    versicolor
# 1    versicolor
# 2    versicolor
# 3    versicolor
# 4    versicolor
# ..          ...
# ...

# %%
eficiencia = (1 - len(errores)/len(iris))*100
eficiencia
# Out:
# 33.333333333333336
